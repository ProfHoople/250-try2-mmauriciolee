# %% [markdown]
# # Homework 5 - Weather Plotting

# %% [markdown]
# In this problem, you'll practice downloading real data from a website and making a plot of the weather over time.
#
# Go to the website http://data.giss.nasa.gov/gistemp/station_data and download the data for San Diego Lindbergh Fld (search for “San Diego” in the Alternative Direct Station Search, probably the first result). You'll need to look carefully to figure out where you can download this data! Choose “csv” as your data format. Note that you may need to right click and “save file as” to download the file as a csv depending on your computer.
#
# Once you have downloaded the file, drag and drop it into the sidebar on the left so you can import it in the next step.

# %%
# Import your libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Import the dataset
station = # Add your code here to read the dataset (ask AI if you can't remember how to import a csv file!)
print(station.head())

# %%
# Create a line plot showing the temperature vs the Annual Mean Temperature (metANN)

plt.figure()  # Create a new figure
sns.lineplot(# Add your code here to plot the temperature over time)

plt.title("Annual Mean Temperature Over Time")
plt.ylabel("Temperature (°C)")

plt.show()

# %%
# This plot doesn't look quite right! It turns out the problem is that the dataset
# contains a placeholder value of 999.90 for missing data. Let's clean that up.

station['metANN Clean'] = station['metANN'].replace(999.90, np.nan) # This code replaces 999.90 with NaN

plt.figure()  # Create a new figure

# Add code to create a line plot using the cleaned data column

plt.title("Annual Mean Temperature Over Time")
plt.ylabel("Temperature (°C)")

plt.show()

# Include your final plot in your homework submission. 
# Don't take a screenshot, save the plot as an image file and then you can copy and paste
# it into your homework submission.

# %% [markdown]
# # Committing Your Work in GitHub Codespaces
#
# Once you've completed your assignment, follow these steps to commit and save your work to GitHub:
#
# 1. **Open Source Control** - Click the Source Control icon in the left sidebar (looks like a branch icon) or press Ctrl/Cmd + Shift + G
#
# 2. **Write a commit message** - In the text box at the top, write a brief message describing your changes (e.g., "Completed HW 5 weather plotting")
#
# 3. **Commit** - Click the Commit button (checkmark icon)
#
# 4. **Sync Changes** - Click the synch changes button to push your commits to GitHub (this means they are saved in your repository!)
#
# Your work is now backed up to GitHub :)
