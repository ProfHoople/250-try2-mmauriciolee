# %% [markdown]
# # Homework 6 - Electricity Sales

# %% [markdown]
# In the left sidebar there is a folder called "data." Inside that folder you'll find the file "EIA Sales of Electricity". This excel file contains contains the table below, this data shows how much electricity was sold to customers in each of the four categories we saw on the Sankey Diagram during the first day of class. In this problem, your job is to create a plot that shows this data visually over time.
#
# ![image.png](attachment:image.png)

# %%
# Import your libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Import the dataset
sales = pd.read_excel('data/EIA Sales of Electricity.xlsx')
print(sales.head())

# %%
# Does this data look right? I don't think so! There are a few rows of information
# before the actual data starts, and the header is not in the first row.
# Ask AI how you can modify the code above to handle this situation. 
# Add your solution below 

sales = 
print(sales.head())

# %%
# Now you'll create a line plot showing the electricity sales over time

plt.figure()  # Create a new figure
sns.lineplot(x="Period", y="Residential", label = "Residential", data=sales)

# To add additional lines for other categories, you can use the same sns.lineplot function 
# and simply modify the 'y' parameter to the respective column names.


# Add code to add a title, xlabel, and ylabel to the plot



plt.show()

# %% [markdown]
# ### Commit your changes to GitHub! (See HW5 if you need a reminder of the steps)
